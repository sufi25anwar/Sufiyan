# %%
Numbers = [5, 10, 15, 20, 25]

# %%
print(Numbers[0])
print(Numbers[-1])
print(Numbers[2])
# Out:
# 5
# 25
# 15

# %%
list = [10, 20, 30, 40, 50]
list.append(60)
list.insert(1, 15)
list.remove(40)
print(list)
# Out:
# [10, 15, 20, 30, 50, 60]

# %%
Movies = ["The Shawshank Redemption", "Coherence", "Interstellar", "The Dark Knight", "Cast Away"]
Total = len(Movies)
print(Total)
# Out:
# 5

# %%
print(Movies [0:])
# Out:
# ['The Shawshank Redemption', 'Coherence', 'Interstellar', 'The Dark Knight', 'Cast Away']
