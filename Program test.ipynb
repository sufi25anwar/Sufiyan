# %%
num1 = 10
num2 = 20
arithmetic_mean = (num1 + num2) / 2
print(f"The arithmetic mean is: {arithmetic_mean}")
# Out:
# The arithmetic mean is: 15.0

# %%
height_m = float((1.75))
weight_kg = float((75))
user_bmi = (75, 1.75)
print(f"The user bmi is: {user_bmi}")
# Out:
# The user bmi is: (75, 1.75)
