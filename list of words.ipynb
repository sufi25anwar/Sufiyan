# %%
words = ["create", "a", "new", "list", "with", "words"]
upper_case = [word.upper() for word in words]
print(upper_case)
# Out:
# ['CREATE', 'A', 'NEW', 'LIST', 'WITH', 'WORDS']

# %%
words[0:3]
# Out:
# ['a', 'create', 'list']

# %%
words.sort()
print(words)
# Out:
# ['a', 'create', 'list', 'new', 'with', 'words']
